# %% [markdown]
# LET'S GO! 😈🔥🔥🔥
#
# ---
#
# # 🏆 ULTIMATE ASSESSMENT — 50 QUESTIONS
#
# **Take your time. Answer everything. No skipping!**
#
# ---
#
# ## SECTION 1 — Variables, Strings & Functions (5 questions)
#
# **Question 1 — Theory:**
# What is the difference between these three?
# ```python
# x = 5
# x = "5"
# x = 5.0
# ```
#
# **Question 2 — Code:**
# What will this output?
# ```python
# name = "muhape"
# print(name.upper())
# print(name.capitalize())
# print(name.replace("m", "M"))
# ```
#
# **Question 3 — Theory:**
# What is the difference between a **parameter** and an **argument?**
# ```python
# def greet(name):      # ← what is "name" here?
#     print(f"Hello {name}")
#
# greet("Muhape")       # ← what is "Muhape" here?
# ```
#
# **Question 4 — Code:**
# What will this output?
# ```python
# def calculate(a, b):
#     return a * b + 10
#
# result = calculate(3, 4)
# print(result)
# ```
#
# **Question 5 — Fix it:**
# Find ALL mistakes:
# ```python
# Def greet(Name):
#     print(f"Hello {name}")
#     return
# greet(Muhape)
# ```
#
# ---
#
# ## SECTION 2 — Conditionals & Logical Operators (6 questions)
#
# **Question 6 — Code:**
# What will this output?
# ```python
# age = 20
# country = "Nigeria"
# if age >= 18 and country == "Nigeria":
#     print("Welcome Nigerian adult!")
# elif age >= 18 and country != "Nigeria":
#     print("Welcome foreign adult!")
# else:
#     print("You are a minor!")
# ```
#
# **Question 7 — Code:**
# What will this output?
# ```python
# x = 15
# if x > 10 or x < 5:
#     print("Condition met!")
# else:
#     print("Condition not met!")
# ```
#
# **Question 8 — Code:**
# What will this output?
# ```python
# is_raining = True
# has_umbrella = False
# if not is_raining or has_umbrella:
#     print("Go outside!")
# else:
#     print("Stay inside!")
# ```
#
# **Question 9 — Theory:**
# What is the difference between `and` and `or`?
# Give one real world Data Science example of each!
#
# **Question 10 — Fix it:**
# ```python
# score = 85
# if score >= 90
#     print("A")
# elif score => 80:
#     print("B")
# else
#     print("C")
# ```
#
# **Question 11 — Code:**
# What will this output?
# ```python
# x = 5
# y = 10
# z = 15
# if x < y and y < z:
#     if z > 10:
#         print("All conditions met!")
#     else:
#         print("Partial conditions!")
# else:
#     print("Conditions failed!")
# ```
#
# ---
#
# ## SECTION 3 — Loops (5 questions)
#
# **Question 12 — Code:**
# What will this output?
# ```python
# total = 0
# for i in range(1, 11):
#     if i % 2 == 0:
#         total += i
# print(total)
# ```
#
# **Question 13 — Code:**
# What will this output?
# ```python
# words = ["Data", "Science", "AI", "Python"]
# for i, word in enumerate(words):
#     if i % 2 == 0:
#         print(word)
# ```
#
# **Question 14 — Build it:**
# Write a loop that prints the **multiplication table of 7** from 1 to 10!
#
# Expected output:
# ```
# 7 x 1 = 7
# 7 x 2 = 14
# ...
# 7 x 10 = 70
# ```
#
# **Question 15 — Code:**
# What will this output?
# ```python
# i = 1
# while i <= 5:
#     print(i * "*")
#     i += 1
# ```
#
# **Question 16 — Code:**
# What will this output?
# ```python
# for i in range(3):
#     for j in range(3):
#         if i == j:
#             print(f"{i},{j}")
# ```
#
# ---
#
# ## SECTION 4 — Lists, Tuples & Sets (8 questions)
#
# **Question 17 — Code:**
# What will this output?
# ```python
# numbers = [3, 1, 4, 1, 5, 9, 2, 6]
# numbers.sort()
# numbers.reverse()
# print(numbers)
# ```
#
# **Question 18 — Code:**
# What will this output?
# ```python
# fruits = ["apple", "mango", "orange", "grape", "banana"]
# print(fruits[1:4])
# print(fruits[::2])
# print(fruits[::-1])
# ```
#
# **Question 19 — Build it:**
# Write code that:
# - Creates a list of 5 numbers
# - Removes duplicates using a set
# - Sorts the result
# - Prints the final list
#
# **Question 20 — Theory:**
# When would you use a **tuple** instead of a **list?**
# Give 2 real world examples!
#
# **Question 21 — Code:**
# What will this output?
# ```python
# coordinates = (10, 20, 30, 20, 10)
# print(coordinates.count(10))
# print(coordinates.index(30))
# ```
#
# **Question 22 — Code:**
# What will this output?
# ```python
# set1 = {1, 2, 3, 4, 5}
# set2 = {4, 5, 6, 7, 8}
# print(set1 & set2)
# print(set1 | set2)
# ```
#
# **Question 23 — Fix it:**
# ```python
# student_grades = [85, 92, 78, 95, 88]
# student_grades.append(90, 87)
# student_grades.insert(95)
# print(student_grades.sort)
# ```
#
# **Question 24 — Build it:**
# Write code that:
# - Takes this list: `[5, 3, 8, 1, 9, 2, 7, 4, 6]`
# - Prints the **highest** number
# - Prints the **lowest** number
# - Prints the **total**
# - Prints the **average**
#
# ---
#
# ## SECTION 5 — Dictionaries (7 questions)
#
# **Question 25 — Code:**
# What will this output?
# ```python
# person = {
#     "name": "Muhape",
#     "age": 19,
#     "skills": ["Python", "Data Science", "AI"]
# }
# print(person["name"])
# print(person["skills"][2])
# print(len(person["skills"]))
# ```
#
# **Question 26 — Build it:**
# Create a dictionary for a hospital patient with:
# - name, age, diagnosis, blood_pressure, temperature
# - Print all keys
# - Print all values
# - Print name and diagnosis only
#
# **Question 27 — Code:**
# What will this output?
# ```python
# scores = {"Muhape": 95, "David": 72, "Sarah": 88}
# scores["John"] = 65
# scores["David"] = 80
# del scores["Sarah"]
# print(scores)
# ```
#
# **Question 28 — Code:**
# What will this output?
# ```python
# students = [
#     {"name": "Muhape", "score": 95},
#     {"name": "David", "score": 65},
#     {"name": "Sarah", "score": 78}
# ]
# for student in students:
#     if student["score"] >= 70:
#         print(f"{student['name']} passed!")
#     else:
#         print(f"{student['name']} failed!")
# ```
#
# **Question 29 — Build it:**
# Write code that loops through this dictionary and prints only students with CGPA above 3.5:
# ```python
# students = {
#     "Muhape": 3.8,
#     "David": 3.2,
#     "Sarah": 3.9,
#     "John": 3.1,
#     "Amina": 3.6
# }
# ```
#
# **Question 30 — Theory:**
# What is the difference between:
# ```python
# student.keys()
# student.values()
# student.items()
# ```
#
# **Question 31 — Fix it:**
# ```python
# patient = {
#     "name": "Amina"
#     "age": 45,
#     "diagnosis": "hypertension"
# }
# print(patient("name"))
# print(patient["height"])
# ```
#
# ---
#
# ## SECTION 6 — Error Handling (5 questions)
#
# **Question 32 — Code:**
# What will this output if user types `"hello"`?
# ```python
# try:
#     number = float(input("Enter number: "))
#     result = 100 / number
# except ValueError:
#     print("Invalid input!")
# except ZeroDivisionError:
#     print("Cannot divide by zero!")
# else:
#     print(f"Result: {result}")
# finally:
#     print("Operation complete!")
# ```
#
# **Question 33 — Build it:**
# Write a function called `safe_sqrt` that:
# - Takes a number
# - Returns its square root
# - Handles negative numbers with a proper error message
# - Uses `finally`
#
# Hint — square root in Python: `x ** 0.5`
#
# **Question 34 — Theory:**
# What is the difference between:
# - `except ValueError`
# - `except Exception as e`
# - `finally`
# - `else`
#
# **Question 35 — Fix it:**
# ```python
# try:
#     age = int(input("Enter age: "))
# except:
#     print("Error!")
# except ValueError:
#     print("Invalid!")
# finally
#     print("Done!")
# ```
#
# **Question 36 — Code:**
# What will this output?
# ```python
# def risky(x):
#     try:
#         return 10 / x
#     except ZeroDivisionError:
#         return "Error!"
#     finally:
#         print("Attempted!")
#
# print(risky(2))
# print(risky(0))
# ```
#
# ---
#
# ## SECTION 7 — File Handling (6 questions)
#
# **Question 37 — Theory:**
# What is the difference between these file modes?
# - `"r"`
# - `"w"`
# - `"a"`
# - `"r+"`
#
# **Question 38 — Build it:**
# Write code that:
# - Creates a file called `students.txt`
# - Writes 3 student names inside it
# - Closes the file properly
#
# **Question 39 — Build it:**
# Write code that:
# - Opens `students.txt`
# - Reads and prints every line
# - Uses `with open` statement
#
# **Question 40 — Theory:**
# Why is `with open()` better than just `open()`?
#
# **Question 41 — Build it:**
# Write code that:
# - Opens a file called `scores.txt`
# - Appends a new score to it
# - Without deleting existing content
#
# **Question 42 — Fix it:**
# ```python
# file = open("data.txt", "r")
# content = file.read
# print(content)
# ```
#
# ---
#
# ## SECTION 8 — Combined Challenges (8 questions)
#
# **Question 43 — Build it:**
# Write a complete program that:
# - Asks user for 5 numbers using a loop
# - Stores them in a list
# - Handles `ValueError` if user types letters
# - Prints highest, lowest, total and average
#
# **Question 44 — Build it:**
# Write a program that:
# - Has a dictionary of 5 students with names and scores
# - Loops through them
# - Assigns grades using conditions
# - Counts passed and failed
# - Writes the results to a file called `results.txt`
#
# **Question 45 — Code:**
# What will this output?
# ```python
# data = [
#     {"name": "Muhape", "scores": [85, 92, 78]},
#     {"name": "David", "scores": [70, 65, 80]},
#     {"name": "Sarah", "scores": [90, 95, 88]}
# ]
# for student in data:
#     average = sum(student["scores"]) / len(student["scores"])
#     print(f"{student['name']}: {average:.1f}")
# ```
#
# **Question 46 — Build it:**
# Write a complete Patient Management System that:
# - Stores 3 patients in a list of dictionaries
# - Checks temperature status
# - Checks blood pressure status
# - Writes full report to a file called `hospital_report.txt`
# - Handles any errors gracefully
#
# **Question 47 — Theory:**
# Explain the complete flow of this code:
# ```python
# def process_data(filename):
#     try:
#         with open(filename, "r") as f:
#             data = f.readlines()
#             numbers = [int(x.strip()) for x in data]
#             return sum(numbers) / len(numbers)
#     except FileNotFoundError:
#         return "File not found!"
#     except ValueError:
#         return "Invalid data in file!"
#     except ZeroDivisionError:
#         return "File is empty!"
#     finally:
#         print("Processing complete!")
# ```
#
# **Question 48 — Build it:**
# Write a complete **Student Grade Management System** that:
# - Keeps running until user types `quit`
# - Asks for student name and score
# - Assigns grade
# - Saves each entry to `grades.txt`
# - Handles all errors
#
# **Question 49 — Theory:**
# Looking at your entire Python journey — explain in your own words how these 5 concepts work together in a real Data Science project:
# - Functions
# - Loops
# - Dictionaries
# - Error handling
# - File handling
#
# **Question 50 — Ultimate Build:**
# Build a complete **Personal Finance Tracker** that:
# - Asks user to enter income and expenses using a loop
# - Stores everything in a list of dictionaries
# - Calculates total income, total expenses and balance
# - Tells user if they are in profit or loss
# - Saves complete report to `finance_report.txt`
# - Handles ALL possible errors
#
# ---
#
# # 🏆 GOOD LUCK MUHAPE! 🏆
#
# **50 questions — everything you know — all in one assessment!**
#
# Take your time, use PyCharm or Jupyter, and answer every single question! 💪😈🔥
#
# **Come back when you're done!** 🇳🇬🚀
