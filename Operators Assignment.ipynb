# %% [markdown]
# #                                             Operators Assignment

# %% [markdown]
# 1.
# - Error
# - False
# - True
# - False
# - True

# %% [markdown]
# 2. age = 24 is a line of code displaying assignment of the number 24 to the variable called age while the age == 24 is showing a comparison between age and 24 stating that age is equal to 24.

# %% [markdown]
# 3. The first line indicates an assignment of the number 75 to score and the execution of the remaining lines output;
# - True
# - False
# - True
# - False

# %% [markdown]
# 4.

# %%
patient_temp = 39.2

patient_temp > 37.5
# Out:
# True

# %%
patient_temp == 39.2
# Out:
# True

# %%
patient_temp != 36.5
# Out:
# True

# %%
patient_temp <= 40
# Out:
# True

# %% [markdown]
# 5.
# - True
# - False
# - True
# - True

# %% [markdown]
# 6.
# - True
# - False
# - True

# %% [markdown]
# 7.
# - True
# - False
# - True

# %% [markdown]
# 8.
# - False
# - True
# - False
# - True

# %% [markdown]
# 9. The last result may be different because of Python's case sensitivity which detects the first letter of the string to be in capital letter in comparison to the original string stored in the variable which contains no capital letters.

# %%
medical_result = "positive"

medical_result == "positive"
# Out:
# True

# %%
medical_result != "negative"
# Out:
# True

# %%
medical_result == "Positive"
# Out:
# False

# %% [markdown]
# 10.

# %%
model_accuracy = 0.91

model_accuracy > 0.90
# Out:
# True

# %%
model_accuracy < 0.95
# Out:
# True

# %%
0.90 < model_accuracy < 0.95
# Out:
# True

# %%
model_accuracy != 1.0
# Out:
# True

# %% [markdown]
# 11.
# - True
# - True
# - False

# %% [markdown]
# 12. temperature > 38 and heart_rate > 100

# %% [markdown]
# 13.
#     score >= 50 and attendance >= 75

# %% [markdown]
# 14.
#     accuracy >= 0.90 and error_rate < 0.10

# %% [markdown]
# 15.
# - no error
# - age = 25
# - score >= 50
# - no error
# - no error

# %% [markdown]
# 16.
# - age > 18
# - score != 0
# - 36 <= temperature <= 38
# - name == "Amina"
# - diagnosis != "malaria"

# %% [markdown]
# 17.
# - True
# - True
# - False
# - True

# %% [markdown]
# 18.
# - temperature > 38 and oxygen_level > 92
# - score >= 50 and attendance >= 80
# - accuracy >= 0.90 and error_rate < 0.10
# - payment_status == True and amount > 3000
