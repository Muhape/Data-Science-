# %% [markdown]
#                                         Assignment solution
# 1.

# %%
from os import name

pwd
# Out:
# 'C:\\Users\\Muham\\PycharmProjects\\lecture1_practice'

# %% [markdown]
# 2.

# %%
# %%writefile clinic.txt
#
# patient name
# diagnosis
# temperature
# Out:
# Writing clinic.txt

# %% [markdown]
# 3.

# %%
with open("clinic.txt") as g:
    print(g.read())
# Out:
# patient name
# diagnosis
# temperature

# %% [markdown]
# 4. The second one returns nothing because the cursor does not have anything to read again after it has completely read the first file.

# %%
with open("clinic.txt") as g:
    print(g.read())
    print(g.read())
# Out:
# patient name
# diagnosis
# temperature

# %% [markdown]
# 5.

# %%
with open("clinic.txt") as g:
    print(g.read())
    g.seek(0)
    print(g.read())
# Out:
# patient name
# diagnosis
# temperature
#
#
# patient name
# diagnosis
# temperature

# %% [markdown]
# 6.

# %%
with open("clinic.txt") as g:
    health = g.read()
print(health)
# Out:
# patient name
# diagnosis
# temperature

# %% [markdown]
# 7.

# %%
with open('scan.txt', 'w') as s:
    s.write('MRI scan completed successfully')

# %% [markdown]
# 8.

# %%
with open('scan.txt', 'a') as s:
    s.write('\nNo abnormality detected.')

# %% [markdown]
# 9.

# %%
with open('scan.txt', 'r') as s:
    print(s.read())
# Out:
# MRI scan completed successfully
# No abnormality detected.

# %% [markdown]
# 10. The read mode allows you to read a file and also show you the content of the file without having the need to go to file and check, while write mode allows you to create a new file and write your desired content in it, or you can also overwrite an existing file with your desired content. Append mode on the other hand allows you to add any content you want to in an existing file without removing or changing anything in the file.

# %% [markdown]
# 11. These are the modes you use for each case
# - Read mode
# - write mode
# - append mode

# %% [markdown]
# 12. file.read() reads the entire file as one string on its own while file.readline() reads a file line by line where each line is read as a different string to the other.

# %% [markdown]
# 13.

# %%
r"C:\Users\USER\Downloads\scan.txt"
# Out:
# 'C:\\Users\\USER\\Downloads\\scan.txt'

# %% [markdown]
# 14. We sometimes put the "r" before the file paths so as not to read the '\' as escape sequences and see everything as a raw string.

# %% [markdown]
# 15. B. with open("scan.txt", "w")

# %% [markdown]
# 16. Using the file path of the python file.

# %% [markdown]
# 17.

# %%
with open("records.txt", 'w') as g:
    g.write(
        "Patient name:Ismail\nPatient age:24\nPatient Diagnosis:Malaria"
    )

# %%
with open("records.txt", 'r') as f:
    print(f.read())
# Out:
# Patient name:Ismail
# Patient age:24
# Patient Diagnosis:Malaria

# %%
with open("records.txt", 'a') as o:
    o.write(
        "\nPatient name:Basit\nPatient age:28\nPatient Diagnosis:Typhoid"
    )

# %%
with open("records.txt", 'r') as f:
    print(f.read())
# Out:
# Patient name:Ismail
# Patient age:24
# Patient Diagnosis:Malaria
# Patient name:Basit
# Patient age:28
# Patient Diagnosis:Typhoid

# %% [markdown]
# 18. Relative file path is a type of file path that relative to the folder where the file is while absolute file path is the file path that is exactly absolute to the file you are dealing with.

# %% [markdown]
# 19. A belongs to windows while B belongs to Mac/Linux

# %% [markdown]
# 20.
# - File handling is very important in data science because it makes accessing, writing, reading and modifying of files very easy and convenient. An example is the application of data science in marketing where you can easily use file handling to access the contents of a file and modify it.
# - File handling is makes it easy in AI for it to check and analyze a file for lots of useful reasons. An example is an AI checking a file for an image or an audio to use it for purposes like recognition or extraction.
# - File handling has many applications in health care which include storing patient records, analysing patient diagnosis and lots more.
