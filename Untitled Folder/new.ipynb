# %%
age = 28
state = "Kwara"
print(f"Hello, my name is {name} I am {age} years old, I live in {state} state")
# Out:
# Hello, my name is {name} I am {age} years old, I live in {state} state

# %%
num1 = int(input("Enter number"))
num2 = int(input("Enter number"))
print(num1 + num2)
# Out:
# Enter number 1
# Enter number 1
# 2
