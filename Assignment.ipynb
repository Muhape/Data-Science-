# %% [markdown]
# Question 1

# %%
from hashlib import file_digest

my_list = ["Muhammed",19,"Unilorin","Python"]
print(my_list)
# Out:
# ['Muhammed', 19, 'Unilorin', 'Python']

# %% [markdown]
# Question 2

# %%
medical_pcv = [20.9,45,37.9,40.1,38.5]
print(medical_pcv[0])
print(medical_pcv[-1])
print(medical_pcv[2])
# Out:
# 20.9
# 38.5
# 37.9

# %% [markdown]
# Question 3

# %%
patient_tempertatures = [36.5,37.1,38.4,39.0,36.9,37.5]
print(patient_tempertatures[1:4])
# Out:
# [37.1, 38.4, 39.0]

# %% [markdown]
# Question 4

# %%
student_scores = [70,85,90]
student_scores.append(95)
print(student_scores)
student_scores.extend([100,65])
print(student_scores)
student_scores.insert(1,80)
print(student_scores)
# Out:
# [70, 85, 90, 95]
# [70, 85, 90, 95, 100, 65]
# [70, 80, 85, 90, 95, 100, 65]

# %% [markdown]
# Question 5

# %%
shopping_list = ["rice","sugar","milk","fan"]
shopping_list.remove("milk")
print(shopping_list)
popped = shopping_list.pop()
print(popped)
shopping_list.reverse()
print(shopping_list)
shopping_list.sort()
print(shopping_list)
# Out:
# ['rice', 'sugar', 'fan']
# fan
# ['sugar', 'rice']
# ['rice', 'sugar']

# %% [markdown]
# Question 6

# %%
drug_names = ["paracetamol","Ibuprofen"]
hospital_drugs = ["Amoxicillin","Metformin"]

drug_names.extend(hospital_drugs)
print(drug_names)
# Out:
# ['paracetamol', 'Ibuprofen', 'Amoxicillin', 'Metformin']

# %% [markdown]
# Question 7

# %%
patient_coordinates = (4.5,7.8)
print(patient_coordinates[1])
# Out:
# 7.8

# %% [markdown]
# Question 8

# %% [markdown]
# 1. This code block will give an error.
# 2. This code block runs successfully.
# 3. This code block gives an error.
# 4. This code block runs successfully.

# %% [markdown]
# Question 9

# %%
numbers = (1,1,2,3,1,4)
print(numbers.count(1))
print(numbers.index(3))
# Out:
# 3
# 3

# %% [markdown]
# Question 10

# %%
my_dict = {
    "name": "David",
    "age": 25,
    "department":"Computer Science",
    "CGPA":4.5
}
print(my_dict)
# Out:
# {'name': 'David', 'age': 25, 'department': 'Computer Science', 'CGPA': 4.5}

# %% [markdown]
# Question 11

# %%
student = {
    "name": "Ridwan",
    "age": 25,
    "skills":["python","sql","machine learning"]
}
print(student["name"])
print(student["skills"][1])
print(student["skills"][1].upper())
# Out:
# Ridwan
# sql
# SQL

# %% [markdown]
# Question 12

# %%
patient_record={
    "name":"Amina",
    "age":45,
    "diagnosis":["hypertension","diabetes"],
    "vitals":(120,80)
}

print(patient_record["name"])
print(patient_record["diagnosis"][0])
print(patient_record["vitals"][0])
# Out:
# Amina
# hypertension
# 120

# %% [markdown]
# Question 13

# %%
employee = {
    "name":"David",
    "salary":250000,
    "Department":"Data Science"
}
employee["salary"] = 300000
employee["country"] = "Nigeria"
print(employee)
# Out:
# {'name': 'David', 'salary': 300000, 'Department': 'Data Science', 'country': 'Nigeria'}

# %% [markdown]
# Question 14

# %%
student = {
    "name": "Ridwan",
    "age": 25,
    "country":"Nigeria"
}
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name', 'age', 'country'])
# dict_values(['Ridwan', 25, 'Nigeria'])
# dict_items([('name', 'Ridwan'), ('age', 25), ('country', 'Nigeria')])

# %% [markdown]
# Question 15

# %%
numbers = {1,1,2,2,3,3,4,4}
print(numbers)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# The output of this set produced {1,2,3,4} because all the items in the set were duplicated initially. Whereas, sets do not allow duplicate items.

# %% [markdown]
# Question 16

# %%
medical_record_numbers = [101,102,101,103,104,102,105]
set_items = set(medical_record_numbers)
print(set_items)
# Out:
# {101, 102, 103, 104, 105}

# %% [markdown]
# Some values from the original list disappeared because I changed the entire list into a set which coes not allow duplicate items. Sets automatically remove duplicate items if a list is converted to it.

# %% [markdown]
# Question 17
#
# * Dictionary
# * Tuple
# * Set
# * List

# %%
with open('muhape.txt') as m:
    print(m.read())
# Out:
# Name: Muhape
# Realm: Ilorin
# Haki: Conquerers Haki
